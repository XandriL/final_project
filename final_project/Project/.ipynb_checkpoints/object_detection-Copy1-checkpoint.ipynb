# %% [markdown]
# ## Mask RCNN

# %%
import datetime
import os
import sys
import json
import numpy as np
import time
import tensorflow as tf
from PIL import Image, ImageDraw

# %%
# Set the ROOT_DIR variable to the root directory of the Mask_RCNN git repo
ROOT_DIR = '../../aktwelve_Mask_RCNN'
assert os.path.exists(ROOT_DIR)

# Import mrcnn libraries
sys.path.append(ROOT_DIR) 
from mrcnn.config import Config
import mrcnn.utils as utils
from mrcnn import visualize
import mrcnn.model as modellib

# %%
# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

# Local path to trained weights file
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")

# Download COCO trained weights from Releases if needed
if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)

# %% [markdown]
# ## Configuration
# Define configuration for new dataset

# %%
class PersonConfig(Config):
    """Configuration for training on the classroom_data dataset.
    Derives from the base Config class and overrides values specific
    to the classroom_data dataset.
    """
    # Give the configuration a recognizable name
    NAME = "Mall"

    # Train on 1 GPU and 1 image per GPU. Batch size is 1 (GPUs * images/GPU).
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1
    
    LEARNING_RATE = 0.002

    # Number of classes (including background)
    NUM_CLASSES = 1 + 1 # background + person 

    # Change this later based on the dimension of images formed from extracting from video
#     IMAGE_MIN_DIM = 256
#     IMAGE_MAX_DIM = 320

    # You can experiment with this number to see if it improves training
    STEPS_PER_EPOCH = 200

    # This is how often validation is run. If you are using too much hard drive space
    # on saved models (in the MODEL_DIR), try making this value larger.
    VALIDATION_STEPS = 4
    
    BACKBONE = 'resnet50'

    RPN_ANCHOR_SCALES = (16, 32, 64, 128,256)
    TRAIN_ROIS_PER_IMAGE = 32
    MAX_GT_INSTANCES = 50 

    
config = PersonConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet50
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.002
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               50
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           Mall
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (16, 32, 64, 128, 256)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                200
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           32
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               4
# WEIGHT_DECAY                   0.0001

# %% [markdown]
# # Define the dataset

# %%
class CocoLikeDataset(utils.Dataset):
    """ Generates a COCO-like dataset, i.e. an image dataset annotated in the style of the COCO dataset.
        See http://cocodataset.org/#home for more information.
    """
    def load_data(self, annotation_json, images_dir):
        """ Load the coco-like dataset from json
        Args:
            annotation_json: The path to the coco annotations json file
            images_dir: The directory holding the images referred to by the json file
        """
        # Load json from file
        json_file = open(annotation_json)
        coco_json = json.load(json_file)
        json_file.close()
        
        # Add the class names using the base method from utils.Dataset
        source_name = "coco_like"
        for category in coco_json['categories']:
            class_id = category['id']
            class_name = category['name']
            if class_id < 1:
                print('Error: Class id for "{}" cannot be less than one. (0 is reserved for the background)'.format(class_name))
                return
            
            self.add_class(source_name, class_id, class_name)
        
        # Get all annotations
        annotations = {}
        for annotation in coco_json['annotations']:
            image_id = annotation['image_id']
            if image_id not in annotations:
                annotations[image_id] = []
            annotations[image_id].append(annotation)
        
        # Get all images and add them to the dataset
        seen_images = {}
        for image in coco_json['images']:
            image_id = image['id']
            if image_id in seen_images:
                print("Warning: Skipping duplicate image id: {}".format(image))
            else:
                seen_images[image_id] = image
                try:
                    image_file_name = image['file_name']
                    image_width = image['width']
                    image_height = image['height']
                except KeyError as key:
                    print("Warning: Skipping image (id: {}) with missing key: {}".format(image_id, key))
                
                image_path = os.path.abspath(os.path.join(images_dir, image_file_name))
                image_annotations = annotations[image_id]
                
                # Add the image using the base method from utils.Dataset
                self.add_image(
                    source=source_name,
                    image_id=image_id,
                    path=image_path,
                    width=image_width,
                    height=image_height,
                    annotations=image_annotations
                )
                
    def load_mask(self, image_id):
        """ Load instance masks for the given image.
        MaskRCNN expects masks in the form of a bitmap [height, width, instances].
        Args:
            image_id: The id of the image to load masks for
        Returns:
            masks: A bool array of shape [height, width, instance count] with
                one mask per instance.
            class_ids: a 1D array of class IDs of the instance masks.
        """
        image_info = self.image_info[image_id]
        annotations = image_info['annotations']
        instance_masks = []
        class_ids = []
        
        for annotation in annotations:
            class_id = annotation['category_id']
            mask = Image.new('1', (image_info['width'], image_info['height']))
            mask_draw = ImageDraw.ImageDraw(mask, '1')
            for segmentation in annotation['segmentation']:
                mask_draw.polygon(segmentation, fill=1)
                bool_array = np.array(mask) > 0
                instance_masks.append(bool_array)
                class_ids.append(class_id)

        mask = np.dstack(instance_masks)
        class_ids = np.array(class_ids, dtype=np.int32)
        
        return mask, class_ids

# %%
dataset_train = CocoLikeDataset()
dataset_train.load_data('../datasets/custom_person/train/trainval.json', '../datasets/custom_person/train/')
dataset_train.prepare()

dataset_val = CocoLikeDataset()
dataset_val.load_data('../datasets/custom_person/test/testval.json', '../datasets/custom_person/tests/')
dataset_val.prepare()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-5a60c4bc74de> in <module>
#       4
#       5 dataset_val = CocoLikeDataset()
# ----> 6 dataset_val.load_data('../datasets/custom_person/val/testval.json', '../datasets/custom_person/val/')
#       7 dataset_val.prepare()
#
# <ipython-input-5-5aee722e418a> in load_data(self, annotation_json, images_dir)
#      10         """
#      11         # Load json from file
# ---> 12         json_file = open(annotation_json)
#      13         coco_json = json.load(json_file)
#      14         json_file.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: '../datasets/custom_person/val/testval.json'

# %% [markdown]
# ## Display a few images from the training dataset

# %%
dataset = dataset_train
image_ids = np.random.choice(dataset.image_ids, 4)
for image_id in image_ids:
    image = dataset.load_image(image_id)
    mask, class_ids = dataset.load_mask(image_id)
    visualize.display_top_masks(image, mask, class_ids, dataset.class_names)

# %% [markdown]
# # Create the Training Model and Train

# %%
# Create model in training mode
model = modellib.MaskRCNN(mode="training", config=config,
                          model_dir=MODEL_DIR)

# %%
# Which weights to start with?
init_with = "coco"  # imagenet, coco, or last

if init_with == "imagenet":
    model.load_weights(model.get_imagenet_weights(), by_name=True)
elif init_with == "coco":
    # Load weights trained on MS COCO, but skip layers that
    # are different due to the different number of classes
    # See README for instructions to download the COCO weights
    model.load_weights(COCO_MODEL_PATH, by_name=True,
                       exclude=["mrcnn_class_logits", "mrcnn_bbox_fc", 
                                "mrcnn_bbox", "mrcnn_mask"])
elif init_with == "last":
    # Load the last model you trained and continue training
    model.load_weights(model.find_last(), by_name=True)

# %% [markdown]
# # Training
# Train in two stages:
#
# 1.Only the heads. Here we're freezing all the backbone layers and training only the randomly initialized layers (i.e. the ones that we didn't use pre-trained weights from MS COCO). To train only the head layers, pass layers='heads' to the train() function.
#
# 2.Fine-tune all layers.

# %%
# Train the head branches
# Passing layers="heads" freezes all layers except the head
# layers. You can also pass a regular expression to select
# which layers to train by name pattern.
start_train = time.time()
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs=5,
            layers='heads')
end_train = time.time()
minutes = round((end_train - start_train) / 60, 2)
print(f'Training took {minutes} minutes')
# Out:
# Starting at epoch 0. LR=0.002
#
# Checkpoint Path: ../../aktwelve_Mask_RCNN\logs\mall20210514T2051\mask_rcnn_mall_{epoch:04d}.h5
# Selecting layers to train
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# rpn_model              (Functional)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 1/5
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\tensorflow\python\framework\indexed_slices.py:437: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training/SGD/gradients/gradients/roi_align_classifier/concat_grad/sub:0", shape=(None,), dtype=int32), values=Tensor("training/SGD/gradients/gradients/roi_align_classifier/concat_grad/GatherV2_2:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("training/SGD/gradients/gradients/roi_align_classifier/concat_grad/Shape:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\tensorflow\python\framework\indexed_slices.py:437: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training/SGD/gradients/gradients/roi_align_classifier/concat_grad/sub_1:0", shape=(None,), dtype=int32), values=Tensor("training/SGD/gradients/gradients/roi_align_classifier/concat_grad/GatherV2_5:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("training/SGD/gradients/gradients/roi_align_classifier/concat_grad/Shape_1:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\tensorflow\python\framework\indexed_slices.py:437: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training/SGD/gradients/gradients/roi_align_classifier/concat_grad/sub_2:0", shape=(None,), dtype=int32), values=Tensor("training/SGD/gradients/gradients/roi_align_classifier/concat_grad/GatherV2_8:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("training/SGD/gradients/gradients/roi_align_classifier/concat_grad/Shape_2:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\tensorflow\python\framework\indexed_slices.py:437: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training/SGD/gradients/gradients/roi_align_classifier/concat_grad/sub_3:0", shape=(None,), dtype=int32), values=Tensor("training/SGD/gradients/gradients/roi_align_classifier/concat_grad/GatherV2_11:0", shape=(None, 7, 7, 256), dtype=float32), dense_shape=Tensor("training/SGD/gradients/gradients/roi_align_classifier/concat_grad/Shape_3:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\tensorflow\python\framework\indexed_slices.py:437: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training/SGD/gradients/gradients/roi_align_mask/concat_grad/sub:0", shape=(None,), dtype=int32), values=Tensor("training/SGD/gradients/gradients/roi_align_mask/concat_grad/GatherV2_2:0", shape=(None, 14, 14, 256), dtype=float32), dense_shape=Tensor("training/SGD/gradients/gradients/roi_align_mask/concat_grad/Shape:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\tensorflow\python\framework\indexed_slices.py:437: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training/SGD/gradients/gradients/roi_align_mask/concat_grad/sub_1:0", shape=(None,), dtype=int32), values=Tensor("training/SGD/gradients/gradients/roi_align_mask/concat_grad/GatherV2_5:0", shape=(None, 14, 14, 256), dtype=float32), dense_shape=Tensor("training/SGD/gradients/gradients/roi_align_mask/concat_grad/Shape_1:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\tensorflow\python\framework\indexed_slices.py:437: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training/SGD/gradients/gradients/roi_align_mask/concat_grad/sub_2:0", shape=(None,), dtype=int32), values=Tensor("training/SGD/gradients/gradients/roi_align_mask/concat_grad/GatherV2_8:0", shape=(None, 14, 14, 256), dtype=float32), dense_shape=Tensor("training/SGD/gradients/gradients/roi_align_mask/concat_grad/Shape_2:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\tensorflow\python\framework\indexed_slices.py:437: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training/SGD/gradients/gradients/roi_align_mask/concat_grad/sub_3:0", shape=(None,), dtype=int32), values=Tensor("training/SGD/gradients/gradients/roi_align_mask/concat_grad/GatherV2_11:0", shape=(None, 14, 14, 256), dtype=float32), dense_shape=Tensor("training/SGD/gradients/gradients/roi_align_mask/concat_grad/Shape_3:0", shape=(4,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\tensorflow\python\framework\indexed_slices.py:437: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("training/SGD/gradients/gradients/ROI/GatherV2_1_grad/Reshape_1:0", shape=(6000,), dtype=int32), values=Tensor("training/SGD/gradients/gradients/ROI/GatherV2_1_grad/Reshape:0", shape=(6000, 4), dtype=float32), dense_shape=Tensor("training/SGD/gradients/gradients/ROI/GatherV2_1_grad/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
#   1/200 [..............................] - ETA: 40:06 - batch: 0.0000e+00 - size: 1.0000 - loss: 3.9190 - rpn_class_loss: 0.0240 - rpn_bbox_loss: 0.8996 - mrcnn_class_loss: 0.5535 - mrcnn_bbox_loss: 2.1439 - mrcnn_mask_loss: 0.2980
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#   2/200 [..............................] - ETA: 28:40 - batch: 0.5000 - size: 1.0000 - loss: 3.5414 - rpn_class_loss: 0.0646 - rpn_bbox_loss: 0.8336 - mrcnn_class_loss: 0.5001 - mrcnn_bbox_loss: 1.7634 - mrcnn_mask_loss: 0.3797
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#   3/200 [..............................] - ETA: 28:23 - batch: 1.0000 - size: 1.0000 - loss: 2.7787 - rpn_class_loss: 0.0543 - rpn_bbox_loss: 0.9611 - mrcnn_class_loss: 0.3346 - mrcnn_bbox_loss: 1.1756 - mrcnn_mask_loss: 0.2531
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#   4/200 [..............................] - ETA: 28:21 - batch: 1.5000 - size: 1.0000 - loss: 2.9536 - rpn_class_loss: 0.0467 - rpn_bbox_loss: 1.2546 - mrcnn_class_loss: 0.2749 - mrcnn_bbox_loss: 1.0881 - mrcnn_mask_loss: 0.2893
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#   5/200 [..............................] - ETA: 28:00 - batch: 2.0000 - size: 1.0000 - loss: 2.7027 - rpn_class_loss: 0.0425 - rpn_bbox_loss: 1.0884 - mrcnn_class_loss: 0.2522 - mrcnn_bbox_loss: 1.0341 - mrcnn_mask_loss: 0.2855
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#   6/200 [..............................] - ETA: 28:24 - batch: 2.5000 - size: 1.0000 - loss: 2.6473 - rpn_class_loss: 0.0371 - rpn_bbox_loss: 1.0323 - mrcnn_class_loss: 0.2799 - mrcnn_bbox_loss: 1.0205 - mrcnn_mask_loss: 0.2775
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#   7/200 [>.............................] - ETA: 30:00 - batch: 3.0000 - size: 1.0000 - loss: 2.6849 - rpn_class_loss: 0.0326 - rpn_bbox_loss: 1.0823 - mrcnn_class_loss: 0.2745 - mrcnn_bbox_loss: 1.0291 - mrcnn_mask_loss: 0.2663
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#   8/200 [>.............................] - ETA: 30:42 - batch: 3.5000 - size: 1.0000 - loss: 2.6552 - rpn_class_loss: 0.0422 - rpn_bbox_loss: 1.0664 - mrcnn_class_loss: 0.2644 - mrcnn_bbox_loss: 1.0118 - mrcnn_mask_loss: 0.2704
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#   9/200 [>.............................] - ETA: 30:27 - batch: 4.0000 - size: 1.0000 - loss: 2.8815 - rpn_class_loss: 0.0618 - rpn_bbox_loss: 1.2712 - mrcnn_class_loss: 0.2523 - mrcnn_bbox_loss: 1.0408 - mrcnn_mask_loss: 0.2554
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  10/200 [>.............................] - ETA: 30:18 - batch: 4.5000 - size: 1.0000 - loss: 2.7345 - rpn_class_loss: 0.0563 - rpn_bbox_loss: 1.1717 - mrcnn_class_loss: 0.2388 - mrcnn_bbox_loss: 1.0144 - mrcnn_mask_loss: 0.2532
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  11/200 [>.............................] - ETA: 30:03 - batch: 5.0000 - size: 1.0000 - loss: 2.5615 - rpn_class_loss: 0.0514 - rpn_bbox_loss: 1.0889 - mrcnn_class_loss: 0.2175 - mrcnn_bbox_loss: 0.9576 - mrcnn_mask_loss: 0.2461
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  12/200 [>.............................] - ETA: 29:50 - batch: 5.5000 - size: 1.0000 - loss: 2.5274 - rpn_class_loss: 0.0475 - rpn_bbox_loss: 1.0783 - mrcnn_class_loss: 0.2018 - mrcnn_bbox_loss: 0.9617 - mrcnn_mask_loss: 0.2381
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  13/200 [>.............................] - ETA: 29:35 - batch: 6.0000 - size: 1.0000 - loss: 2.6906 - rpn_class_loss: 0.0549 - rpn_bbox_loss: 1.2714 - mrcnn_class_loss: 0.1896 - mrcnn_bbox_loss: 0.9407 - mrcnn_mask_loss: 0.2339
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  14/200 [=>............................] - ETA: 29:26 - batch: 6.5000 - size: 1.0000 - loss: 2.5857 - rpn_class_loss: 0.0514 - rpn_bbox_loss: 1.2013 - mrcnn_class_loss: 0.1818 - mrcnn_bbox_loss: 0.9107 - mrcnn_mask_loss: 0.2404
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  15/200 [=>............................] - ETA: 29:12 - batch: 7.0000 - size: 1.0000 - loss: 2.5805 - rpn_class_loss: 0.0500 - rpn_bbox_loss: 1.1673 - mrcnn_class_loss: 0.1999 - mrcnn_bbox_loss: 0.9083 - mrcnn_mask_loss: 0.2550
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  16/200 [=>............................] - ETA: 29:01 - batch: 7.5000 - size: 1.0000 - loss: 2.5106 - rpn_class_loss: 0.0473 - rpn_bbox_loss: 1.0991 - mrcnn_class_loss: 0.1891 - mrcnn_bbox_loss: 0.9249 - mrcnn_mask_loss: 0.2502
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  17/200 [=>............................] - ETA: 28:55 - batch: 8.0000 - size: 1.0000 - loss: 2.4895 - rpn_class_loss: 0.0459 - rpn_bbox_loss: 1.0625 - mrcnn_class_loss: 0.1950 - mrcnn_bbox_loss: 0.9254 - mrcnn_mask_loss: 0.2608
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  18/200 [=>............................] - ETA: 28:43 - batch: 8.5000 - size: 1.0000 - loss: 2.6636 - rpn_class_loss: 0.0474 - rpn_bbox_loss: 1.2270 - mrcnn_class_loss: 0.1869 - mrcnn_bbox_loss: 0.9483 - mrcnn_mask_loss: 0.2539
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  19/200 [=>............................] - ETA: 28:38 - batch: 9.0000 - size: 1.0000 - loss: 2.6264 - rpn_class_loss: 0.0461 - rpn_bbox_loss: 1.1976 - mrcnn_class_loss: 0.1863 - mrcnn_bbox_loss: 0.9334 - mrcnn_mask_loss: 0.2630
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  20/200 [==>...........................] - ETA: 28:28 - batch: 9.5000 - size: 1.0000 - loss: 2.5975 - rpn_class_loss: 0.0439 - rpn_bbox_loss: 1.1675 - mrcnn_class_loss: 0.1926 - mrcnn_bbox_loss: 0.9129 - mrcnn_mask_loss: 0.2806
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  21/200 [==>...........................] - ETA: 28:17 - batch: 10.0000 - size: 1.0000 - loss: 2.5472 - rpn_class_loss: 0.0419 - rpn_bbox_loss: 1.1382 - mrcnn_class_loss: 0.1873 - mrcnn_bbox_loss: 0.8944 - mrcnn_mask_loss: 0.2854
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  22/200 [==>...........................] - ETA: 28:12 - batch: 10.5000 - size: 1.0000 - loss: 2.5182 - rpn_class_loss: 0.0402 - rpn_bbox_loss: 1.1190 - mrcnn_class_loss: 0.2008 - mrcnn_bbox_loss: 0.8720 - mrcnn_mask_loss: 0.2862
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  23/200 [==>...........................] - ETA: 28:04 - batch: 11.0000 - size: 1.0000 - loss: 2.4914 - rpn_class_loss: 0.0408 - rpn_bbox_loss: 1.0954 - mrcnn_class_loss: 0.1933 - mrcnn_bbox_loss: 0.8694 - mrcnn_mask_loss: 0.2925
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  24/200 [==>...........................] - ETA: 27:47 - batch: 11.5000 - size: 1.0000 - loss: 2.5038 - rpn_class_loss: 0.0478 - rpn_bbox_loss: 1.0888 - mrcnn_class_loss: 0.2084 - mrcnn_bbox_loss: 0.8632 - mrcnn_mask_loss: 0.2956
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  25/200 [==>...........................] - ETA: 27:29 - batch: 12.0000 - size: 1.0000 - loss: 2.5145 - rpn_class_loss: 0.0460 - rpn_bbox_loss: 1.0846 - mrcnn_class_loss: 0.2088 - mrcnn_bbox_loss: 0.8795 - mrcnn_mask_loss: 0.2955
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  26/200 [==>...........................] - ETA: 27:11 - batch: 12.5000 - size: 1.0000 - loss: 2.5004 - rpn_class_loss: 0.0446 - rpn_bbox_loss: 1.0560 - mrcnn_class_loss: 0.2117 - mrcnn_bbox_loss: 0.8914 - mrcnn_mask_loss: 0.2968
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  27/200 [===>..........................] - ETA: 26:59 - batch: 13.0000 - size: 1.0000 - loss: 2.4709 - rpn_class_loss: 0.0441 - rpn_bbox_loss: 1.0423 - mrcnn_class_loss: 0.2077 - mrcnn_bbox_loss: 0.8810 - mrcnn_mask_loss: 0.2958
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  28/200 [===>..........................] - ETA: 26:47 - batch: 13.5000 - size: 1.0000 - loss: 2.4578 - rpn_class_loss: 0.0432 - rpn_bbox_loss: 1.0276 - mrcnn_class_loss: 0.2118 - mrcnn_bbox_loss: 0.8794 - mrcnn_mask_loss: 0.2957
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  29/200 [===>..........................] - ETA: 26:30 - batch: 14.0000 - size: 1.0000 - loss: 2.4546 - rpn_class_loss: 0.0424 - rpn_bbox_loss: 1.0462 - mrcnn_class_loss: 0.2063 - mrcnn_bbox_loss: 0.8668 - mrcnn_mask_loss: 0.2927
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  30/200 [===>..........................] - ETA: 26:11 - batch: 14.5000 - size: 1.0000 - loss: 2.4613 - rpn_class_loss: 0.0411 - rpn_bbox_loss: 1.0237 - mrcnn_class_loss: 0.2060 - mrcnn_bbox_loss: 0.8964 - mrcnn_mask_loss: 0.2941
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  31/200 [===>..........................] - ETA: 25:52 - batch: 15.0000 - size: 1.0000 - loss: 2.4148 - rpn_class_loss: 0.0400 - rpn_bbox_loss: 1.0038 - mrcnn_class_loss: 0.2001 - mrcnn_bbox_loss: 0.8769 - mrcnn_mask_loss: 0.2938
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  32/200 [===>..........................] - ETA: 25:34 - batch: 15.5000 - size: 1.0000 - loss: 2.3564 - rpn_class_loss: 0.0404 - rpn_bbox_loss: 0.9879 - mrcnn_class_loss: 0.1939 - mrcnn_bbox_loss: 0.8495 - mrcnn_mask_loss: 0.2847
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  33/200 [===>..........................] - ETA: 25:16 - batch: 16.0000 - size: 1.0000 - loss: 2.3319 - rpn_class_loss: 0.0399 - rpn_bbox_loss: 0.9757 - mrcnn_class_loss: 0.1927 - mrcnn_bbox_loss: 0.8410 - mrcnn_mask_loss: 0.2827
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  34/200 [====>.........................] - ETA: 25:01 - batch: 16.5000 - size: 1.0000 - loss: 2.3322 - rpn_class_loss: 0.0429 - rpn_bbox_loss: 0.9690 - mrcnn_class_loss: 0.1947 - mrcnn_bbox_loss: 0.8410 - mrcnn_mask_loss: 0.2845
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  35/200 [====>.........................] - ETA: 24:46 - batch: 17.0000 - size: 1.0000 - loss: 2.3407 - rpn_class_loss: 0.0420 - rpn_bbox_loss: 0.9856 - mrcnn_class_loss: 0.1901 - mrcnn_bbox_loss: 0.8431 - mrcnn_mask_loss: 0.2799
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  36/200 [====>.........................] - ETA: 24:30 - batch: 17.5000 - size: 1.0000 - loss: 2.3224 - rpn_class_loss: 0.0414 - rpn_bbox_loss: 0.9824 - mrcnn_class_loss: 0.1871 - mrcnn_bbox_loss: 0.8322 - mrcnn_mask_loss: 0.2794
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  37/200 [====>.........................] - ETA: 24:17 - batch: 18.0000 - size: 1.0000 - loss: 2.3362 - rpn_class_loss: 0.0430 - rpn_bbox_loss: 0.9764 - mrcnn_class_loss: 0.1918 - mrcnn_bbox_loss: 0.8449 - mrcnn_mask_loss: 0.2801
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  38/200 [====>.........................] - ETA: 24:02 - batch: 18.5000 - size: 1.0000 - loss: 2.4101 - rpn_class_loss: 0.0486 - rpn_bbox_loss: 1.0343 - mrcnn_class_loss: 0.1952 - mrcnn_bbox_loss: 0.8406 - mrcnn_mask_loss: 0.2913
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  39/200 [====>.........................] - ETA: 23:47 - batch: 19.0000 - size: 1.0000 - loss: 2.3791 - rpn_class_loss: 0.0474 - rpn_bbox_loss: 1.0144 - mrcnn_class_loss: 0.1941 - mrcnn_bbox_loss: 0.8342 - mrcnn_mask_loss: 0.2890
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  40/200 [=====>........................] - ETA: 23:33 - batch: 19.5000 - size: 1.0000 - loss: 2.3761 - rpn_class_loss: 0.0463 - rpn_bbox_loss: 1.0070 - mrcnn_class_loss: 0.1903 - mrcnn_bbox_loss: 0.8425 - mrcnn_mask_loss: 0.2902
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  41/200 [=====>........................] - ETA: 23:22 - batch: 20.0000 - size: 1.0000 - loss: 2.3759 - rpn_class_loss: 0.0463 - rpn_bbox_loss: 0.9949 - mrcnn_class_loss: 0.2063 - mrcnn_bbox_loss: 0.8362 - mrcnn_mask_loss: 0.2923
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  42/200 [=====>........................] - ETA: 23:13 - batch: 20.5000 - size: 1.0000 - loss: 2.4123 - rpn_class_loss: 0.0463 - rpn_bbox_loss: 1.0391 - mrcnn_class_loss: 0.2030 - mrcnn_bbox_loss: 0.8315 - mrcnn_mask_loss: 0.2924
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  43/200 [=====>........................] - ETA: 23:08 - batch: 21.0000 - size: 1.0000 - loss: 2.4116 - rpn_class_loss: 0.0479 - rpn_bbox_loss: 1.0442 - mrcnn_class_loss: 0.2009 - mrcnn_bbox_loss: 0.8237 - mrcnn_mask_loss: 0.2949
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  44/200 [=====>........................] - ETA: 23:00 - batch: 21.5000 - size: 1.0000 - loss: 2.4616 - rpn_class_loss: 0.0491 - rpn_bbox_loss: 1.1008 - mrcnn_class_loss: 0.1968 - mrcnn_bbox_loss: 0.8243 - mrcnn_mask_loss: 0.2907
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  45/200 [=====>........................] - ETA: 22:51 - batch: 22.0000 - size: 1.0000 - loss: 2.4350 - rpn_class_loss: 0.0490 - rpn_bbox_loss: 1.0874 - mrcnn_class_loss: 0.1950 - mrcnn_bbox_loss: 0.8141 - mrcnn_mask_loss: 0.2895
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  46/200 [=====>........................] - ETA: 22:45 - batch: 22.5000 - size: 1.0000 - loss: 2.4115 - rpn_class_loss: 0.0489 - rpn_bbox_loss: 1.0765 - mrcnn_class_loss: 0.1919 - mrcnn_bbox_loss: 0.8042 - mrcnn_mask_loss: 0.2900
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  47/200 [======>.......................] - ETA: 22:40 - batch: 23.0000 - size: 1.0000 - loss: 2.3945 - rpn_class_loss: 0.0480 - rpn_bbox_loss: 1.0736 - mrcnn_class_loss: 0.1885 - mrcnn_bbox_loss: 0.7957 - mrcnn_mask_loss: 0.2886
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  48/200 [======>.......................] - ETA: 22:35 - batch: 23.5000 - size: 1.0000 - loss: 2.4265 - rpn_class_loss: 0.0484 - rpn_bbox_loss: 1.1069 - mrcnn_class_loss: 0.1862 - mrcnn_bbox_loss: 0.7961 - mrcnn_mask_loss: 0.2889
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  49/200 [======>.......................] - ETA: 22:25 - batch: 24.0000 - size: 1.0000 - loss: 2.3917 - rpn_class_loss: 0.0481 - rpn_bbox_loss: 1.0906 - mrcnn_class_loss: 0.1824 - mrcnn_bbox_loss: 0.7832 - mrcnn_mask_loss: 0.2874
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  50/200 [======>.......................] - ETA: 22:15 - batch: 24.5000 - size: 1.0000 - loss: 2.3598 - rpn_class_loss: 0.0473 - rpn_bbox_loss: 1.0740 - mrcnn_class_loss: 0.1801 - mrcnn_bbox_loss: 0.7741 - mrcnn_mask_loss: 0.2843
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  51/200 [======>.......................] - ETA: 22:05 - batch: 25.0000 - size: 1.0000 - loss: 2.3547 - rpn_class_loss: 0.0466 - rpn_bbox_loss: 1.0666 - mrcnn_class_loss: 0.1827 - mrcnn_bbox_loss: 0.7732 - mrcnn_mask_loss: 0.2856
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  52/200 [======>.......................] - ETA: 21:53 - batch: 25.5000 - size: 1.0000 - loss: 2.3531 - rpn_class_loss: 0.0458 - rpn_bbox_loss: 1.0740 - mrcnn_class_loss: 0.1817 - mrcnn_bbox_loss: 0.7652 - mrcnn_mask_loss: 0.2863
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  53/200 [======>.......................] - ETA: 21:41 - batch: 26.0000 - size: 1.0000 - loss: 2.3540 - rpn_class_loss: 0.0458 - rpn_bbox_loss: 1.0671 - mrcnn_class_loss: 0.1861 - mrcnn_bbox_loss: 0.7603 - mrcnn_mask_loss: 0.2947
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  54/200 [=======>......................] - ETA: 21:30 - batch: 26.5000 - size: 1.0000 - loss: 2.3458 - rpn_class_loss: 0.0458 - rpn_bbox_loss: 1.0565 - mrcnn_class_loss: 0.1849 - mrcnn_bbox_loss: 0.7614 - mrcnn_mask_loss: 0.2972
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  55/200 [=======>......................] - ETA: 21:20 - batch: 27.0000 - size: 1.0000 - loss: 2.3499 - rpn_class_loss: 0.0451 - rpn_bbox_loss: 1.0640 - mrcnn_class_loss: 0.1818 - mrcnn_bbox_loss: 0.7627 - mrcnn_mask_loss: 0.2963
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  56/200 [=======>......................] - ETA: 21:11 - batch: 27.5000 - size: 1.0000 - loss: 2.3351 - rpn_class_loss: 0.0447 - rpn_bbox_loss: 1.0610 - mrcnn_class_loss: 0.1793 - mrcnn_bbox_loss: 0.7550 - mrcnn_mask_loss: 0.2951
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  57/200 [=======>......................] - ETA: 21:01 - batch: 28.0000 - size: 1.0000 - loss: 2.3159 - rpn_class_loss: 0.0440 - rpn_bbox_loss: 1.0514 - mrcnn_class_loss: 0.1768 - mrcnn_bbox_loss: 0.7493 - mrcnn_mask_loss: 0.2944
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  58/200 [=======>......................] - ETA: 20:51 - batch: 28.5000 - size: 1.0000 - loss: 2.3479 - rpn_class_loss: 0.0435 - rpn_bbox_loss: 1.0794 - mrcnn_class_loss: 0.1780 - mrcnn_bbox_loss: 0.7460 - mrcnn_mask_loss: 0.3011
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  59/200 [=======>......................] - ETA: 20:40 - batch: 29.0000 - size: 1.0000 - loss: 2.3373 - rpn_class_loss: 0.0436 - rpn_bbox_loss: 1.0727 - mrcnn_class_loss: 0.1765 - mrcnn_bbox_loss: 0.7434 - mrcnn_mask_loss: 0.3011
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  60/200 [========>.....................] - ETA: 20:30 - batch: 29.5000 - size: 1.0000 - loss: 2.3494 - rpn_class_loss: 0.0431 - rpn_bbox_loss: 1.0833 - mrcnn_class_loss: 0.1775 - mrcnn_bbox_loss: 0.7414 - mrcnn_mask_loss: 0.3041
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  61/200 [========>.....................] - ETA: 20:19 - batch: 30.0000 - size: 1.0000 - loss: 2.3444 - rpn_class_loss: 0.0429 - rpn_bbox_loss: 1.0893 - mrcnn_class_loss: 0.1764 - mrcnn_bbox_loss: 0.7340 - mrcnn_mask_loss: 0.3017
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  62/200 [========>.....................] - ETA: 20:08 - batch: 30.5000 - size: 1.0000 - loss: 2.3305 - rpn_class_loss: 0.0427 - rpn_bbox_loss: 1.0813 - mrcnn_class_loss: 0.1769 - mrcnn_bbox_loss: 0.7284 - mrcnn_mask_loss: 0.3012
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  63/200 [========>.....................] - ETA: 19:58 - batch: 31.0000 - size: 1.0000 - loss: 2.3177 - rpn_class_loss: 0.0427 - rpn_bbox_loss: 1.0750 - mrcnn_class_loss: 0.1774 - mrcnn_bbox_loss: 0.7204 - mrcnn_mask_loss: 0.3021
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
#  64/200 [========>.....................] - ETA: 19:46 - batch: 31.5000 - size: 1.0000 - loss: 2.3153 - rpn_class_loss: 0.0421 - rpn_bbox_loss: 1.0752 - mrcnn_class_loss: 0.1784 - mrcnn_bbox_loss: 0.7169 - mrcnn_mask_loss: 0.3027
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
# ...
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
# 179/200 [=========================>....] - ETA: 2:23 - batch: 89.0000 - size: 1.0000 - loss: 1.5375 - rpn_class_loss: 0.0310 - rpn_bbox_loss: 0.8701 - mrcnn_class_loss: 0.1420 - mrcnn_bbox_loss: 0.2117 - mrcnn_mask_loss: 0.2828
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
# 180/200 [==========================>...] - ETA: 2:16 - batch: 89.5000 - size: 1.0000 - loss: 1.5335 - rpn_class_loss: 0.0308 - rpn_bbox_loss: 0.8682 - mrcnn_class_loss: 0.1418 - mrcnn_bbox_loss: 0.2110 - mrcnn_mask_loss: 0.2817
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
# 181/200 [==========================>...] - ETA: 2:10 - batch: 90.0000 - size: 1.0000 - loss: 1.5418 - rpn_class_loss: 0.0308 - rpn_bbox_loss: 0.8670 - mrcnn_class_loss: 0.1475 - mrcnn_bbox_loss: 0.2133 - mrcnn_mask_loss: 0.2833
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
# 182/200 [==========================>...] - ETA: 2:03 - batch: 90.5000 - size: 1.0000 - loss: 1.5465 - rpn_class_loss: 0.0314 - rpn_bbox_loss: 0.8700 - mrcnn_class_loss: 0.1470 - mrcnn_bbox_loss: 0.2135 - mrcnn_mask_loss: 0.2847
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
# 183/200 [==========================>...] - ETA: 1:56 - batch: 91.0000 - size: 1.0000 - loss: 1.5430 - rpn_class_loss: 0.0312 - rpn_bbox_loss: 0.8675 - mrcnn_class_loss: 0.1463 - mrcnn_bbox_loss: 0.2134 - mrcnn_mask_loss: 0.2846
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
# 184/200 [==========================>...] - ETA: 1:49 - batch: 91.5000 - size: 1.0000 - loss: 1.5497 - rpn_class_loss: 0.0312 - rpn_bbox_loss: 0.8757 - mrcnn_class_loss: 0.1456 - mrcnn_bbox_loss: 0.2132 - mrcnn_mask_loss: 0.2839
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
# 185/200 [==========================>...] - ETA: 1:42 - batch: 92.0000 - size: 1.0000 - loss: 1.5470 - rpn_class_loss: 0.0310 - rpn_bbox_loss: 0.8730 - mrcnn_class_loss: 0.1453 - mrcnn_bbox_loss: 0.2132 - mrcnn_mask_loss: 0.2845
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
# 186/200 [==========================>...] - ETA: 1:36 - batch: 92.5000 - size: 1.0000 - loss: 1.5480 - rpn_class_loss: 0.0309 - rpn_bbox_loss: 0.8718 - mrcnn_class_loss: 0.1464 - mrcnn_bbox_loss: 0.2137 - mrcnn_mask_loss: 0.2850
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
# 187/200 [===========================>..] - ETA: 1:29 - batch: 93.0000 - size: 1.0000 - loss: 1.5454 - rpn_class_loss: 0.0309 - rpn_bbox_loss: 0.8696 - mrcnn_class_loss: 0.1464 - mrcnn_bbox_loss: 0.2137 - mrcnn_mask_loss: 0.2848
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
# 188/200 [===========================>..] - ETA: 1:22 - batch: 93.5000 - size: 1.0000 - loss: 1.5415 - rpn_class_loss: 0.0307 - rpn_bbox_loss: 0.8665 - mrcnn_class_loss: 0.1461 - mrcnn_bbox_loss: 0.2133 - mrcnn_mask_loss: 0.2848
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
# 189/200 [===========================>..] - ETA: 1:15 - batch: 94.0000 - size: 1.0000 - loss: 1.5373 - rpn_class_loss: 0.0308 - rpn_bbox_loss: 0.8637 - mrcnn_class_loss: 0.1458 - mrcnn_bbox_loss: 0.2130 - mrcnn_mask_loss: 0.2841
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
# 190/200 [===========================>..] - ETA: 1:08 - batch: 94.5000 - size: 1.0000 - loss: 1.5326 - rpn_class_loss: 0.0306 - rpn_bbox_loss: 0.8602 - mrcnn_class_loss: 0.1451 - mrcnn_bbox_loss: 0.2129 - mrcnn_mask_loss: 0.2838
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
# 191/200 [===========================>..] - ETA: 1:01 - batch: 95.0000 - size: 1.0000 - loss: 1.5329 - rpn_class_loss: 0.0307 - rpn_bbox_loss: 0.8581 - mrcnn_class_loss: 0.1456 - mrcnn_bbox_loss: 0.2143 - mrcnn_mask_loss: 0.2842
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
# 192/200 [===========================>..] - ETA: 55s - batch: 95.5000 - size: 1.0000 - loss: 1.5342 - rpn_class_loss: 0.0307 - rpn_bbox_loss: 0.8627 - mrcnn_class_loss: 0.1449 - mrcnn_bbox_loss: 0.2132 - mrcnn_mask_loss: 0.2827
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
# 193/200 [===========================>..] - ETA: 48s - batch: 96.0000 - size: 1.0000 - loss: 1.5319 - rpn_class_loss: 0.0306 - rpn_bbox_loss: 0.8595 - mrcnn_class_loss: 0.1444 - mrcnn_bbox_loss: 0.2141 - mrcnn_mask_loss: 0.2833
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
# 194/200 [============================>.] - ETA: 41s - batch: 96.5000 - size: 1.0000 - loss: 1.5278 - rpn_class_loss: 0.0305 - rpn_bbox_loss: 0.8570 - mrcnn_class_loss: 0.1440 - mrcnn_bbox_loss: 0.2133 - mrcnn_mask_loss: 0.2829
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
# 195/200 [============================>.] - ETA: 34s - batch: 97.0000 - size: 1.0000 - loss: 1.5249 - rpn_class_loss: 0.0304 - rpn_bbox_loss: 0.8553 - mrcnn_class_loss: 0.1444 - mrcnn_bbox_loss: 0.2126 - mrcnn_mask_loss: 0.2822
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
# 196/200 [============================>.] - ETA: 27s - batch: 97.5000 - size: 1.0000 - loss: 1.5233 - rpn_class_loss: 0.0303 - rpn_bbox_loss: 0.8529 - mrcnn_class_loss: 0.1442 - mrcnn_bbox_loss: 0.2131 - mrcnn_mask_loss: 0.2828
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
# 197/200 [============================>.] - ETA: 20s - batch: 98.0000 - size: 1.0000 - loss: 1.5202 - rpn_class_loss: 0.0302 - rpn_bbox_loss: 0.8498 - mrcnn_class_loss: 0.1442 - mrcnn_bbox_loss: 0.2130 - mrcnn_mask_loss: 0.2829
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
# 198/200 [============================>.] - ETA: 13s - batch: 98.5000 - size: 1.0000 - loss: 1.5192 - rpn_class_loss: 0.0302 - rpn_bbox_loss: 0.8468 - mrcnn_class_loss: 0.1437 - mrcnn_bbox_loss: 0.2140 - mrcnn_mask_loss: 0.2844
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
# 199/200 [============================>.] - ETA: 6s - batch: 99.0000 - size: 1.0000 - loss: 1.5204 - rpn_class_loss: 0.0302 - rpn_bbox_loss: 0.8497 - mrcnn_class_loss: 0.1434 - mrcnn_bbox_loss: 0.2137 - mrcnn_mask_loss: 0.2834
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
# 200/200 [==============================] - ETA: 0s - batch: 99.5000 - size: 1.0000 - loss: 1.5210 - rpn_class_loss: 0.0301 - rpn_bbox_loss: 0.8491 - mrcnn_class_loss: 0.1443 - mrcnn_bbox_loss: 0.2138 - mrcnn_mask_loss: 0.2837
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\skimage\transform\_warps.py:830: FutureWarning: Input image dtype is bool. Interpolation is not defined with bool data type. Please set order to 0 or explicitely cast input image to another data type. Starting from version 0.19 a ValueError will be raised instead of this warning.
#   order = _validate_interpolation_order(image.dtype, order)
# 200/200 [==============================] - 1396s 7s/step - batch: 99.5000 - size: 1.0000 - loss: 1.5210 - rpn_class_loss: 0.0301 - rpn_bbox_loss: 0.8491 - mrcnn_class_loss: 0.1443 - mrcnn_bbox_loss: 0.2138 - mrcnn_mask_loss: 0.2837 - val_loss: 0.7436 - val_rpn_class_loss: 0.0055 - val_rpn_bbox_loss: 0.2748 - val_mrcnn_class_loss: 0.1145 - val_mrcnn_bbox_loss: 0.1562 - val_mrcnn_mask_loss: 0.1927
# Training took 127.95 minutes

# %% [markdown]
# # Prepare to run Inference

# %%
class InferenceConfig(PersonConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1
    DETECTION_MIN_CONFIDENCE = 0.85
    

inference_config = InferenceConfig()

# %%
# Recreate the model in inference mode
model = modellib.MaskRCNN(mode="inference", 
                          config=inference_config,
                          model_dir=MODEL_DIR)
# Out:
# WARNING:tensorflow:From C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\tensorflow\python\util\deprecation.py:605: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead

# %%
# Get path to saved weights
# Either set a specific path or find last trained weights
# model_path = os.path.join(ROOT_DIR, ".h5 file name here")
#model_path = os.path.join(MODEL_DIR,"classroom20210328T1024/mask_rcnn_classroom_0003.h5")
model_path = model.find_last()

# Load trained weights (fill in path to trained weights here)
assert model_path != "", "Provide path to trained weights"
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True, exclude=["mrcnn_class_logits", "mrcnn_bbox_fc", "mrcnn_bbox", "mrcnn_mask"])
# Out:
# Loading weights from  ../../aktwelve_Mask_RCNN\logs\mall20210514T2051\mask_rcnn_mall_0005.h5
# Re-starting from epoch 5

# %% [markdown]
# # Run Inference
# Run model.detect() on real images.
#
# We get some false positives, and some misses. More training images are likely needed to improve the results.

# %%
import skimage
real_test_dir = '../datasets/caviar set/real_test/' #change this location of test_dir
image_paths = []
for filename in os.listdir(real_test_dir):
    if os.path.splitext(filename)[1].lower() in ['.png', '.jpg', '.jpeg']:
        image_paths.append(os.path.join(real_test_dir, filename))

for image_path in image_paths:
    img = skimage.io.imread(image_path)
    img_arr = np.array(img)
    results = model.detect([img_arr], verbose=1)
    r = results[0]
    visualize.display_instances(img, r['rois'], r['masks'], r['class_ids'], 
                                dataset_val.class_names, r['scores'], figsize=(5,5))
# Out:
# Processing 1 images
# image                    shape: (288, 384, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.17695  max:    1.11439  float32
# C:\Users\nipun\anaconda3\envs\mask_rcnn\lib\site-packages\tensorflow\python\keras\engine\training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# <img src="data:image/png;base64,..." width="500">
# Processing 1 images
# image                    shape: (288, 384, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.17695  max:    1.11439  float32
# <img src="data:image/png;base64,..." width="500">
# Processing 1 images
# image                    shape: (288, 384, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.17695  max:    1.11439  float32
# <img src="data:image/png;base64,..." width="500">
# Processing 1 images
# image                    shape: (288, 384, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.17695  max:    1.11439  float32
# <div id='feb41e21-2c26-48ce-aa10-7b73a6e397d8'></div>
# Processing 1 images
# image                    shape: (288, 384, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.17695  max:    1.11439  float32
# <div id='fe5f935c-0f15-49b5-9c27-7dd06bc64309'></div>
# Processing 1 images
# image                    shape: (288, 384, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.17695  max:    1.11439  float32
# <div id='966a75ff-c925-47ac-8a29-d7141e6bdd7b'></div>
# Processing 1 images
# image                    shape: (288, 384, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.17695  max:    1.11439  float32
# <div id='e96a98d3-a575-4335-8c25-9b2df246c8b1'></div>
# Processing 1 images
# image                    shape: (288, 384, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.17695  max:    1.11439  float32
# <div id='5f0f331d-c51a-4fa5-ba0b-1743330b9398'></div>
# Processing 1 images
# image                    shape: (288, 384, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.17695  max:    1.11439  float32
# <div id='a726217a-6dfe-4ef2-ab15-567b9a750b4d'></div>
# Processing 1 images
# image                    shape: (288, 384, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.17695  max:    1.11439  float32
# <div id='dcd68e5b-6be7-4ece-837c-2637617c5686'></div>
# Processing 1 images
# image                    shape: (288, 384, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.17695  max:    1.11439  float32
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-c67c30198010> in <module>
#       9     img = skimage.io.imread(image_path)
#      10     img_arr = np.array(img)
# ---> 11     results = model.detect([img_arr], verbose=1)
#      12     r = results[0]
#      13     visualize.display_instances(img, r['rois'], r['masks'], r['class_ids'],
#
# ~\anaconda3\envs\mask_rcnn\lib\site-packages\mask_rcnn-2.1-py3.7.egg\mrcnn\model.py in detect(self, images, verbose)
#    2515         # Run object detection
#    2516         detections, _, _, mrcnn_mask, _, _, _ =\
# -> 2517             self.keras_model.predict([molded_images, image_metas, anchors], verbose=0)
#    2518         # Process detections
#    2519         results = []
#
# ~\anaconda3\envs\mask_rcnn\lib\site-packages\tensorflow\python\keras\engine\training_v1.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#     989         max_queue_size=max_queue_size,
#     990         workers=workers,
# --> 991         use_multiprocessing=use_multiprocessing)
#     992
#     993   def reset_metrics(self):
#
# ~\anaconda3\envs\mask_rcnn\lib\site-packages\tensorflow\python\keras\engine\training_arrays_v1.py in predict(self, model, x, batch_size, verbose, steps, callbacks, **kwargs)
#     710         verbose=verbose,
#     711         steps=steps,
# --> 712         callbacks=callbacks)
#
# ~\anaconda3\envs\mask_rcnn\lib\site-packages\tensorflow\python\keras\engine\training_arrays_v1.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     382
#     383         # Get outputs.
# --> 384         batch_outs = f(ins_batch)
#     385         if not isinstance(batch_outs, list):
#     386           batch_outs = [batch_outs]
#
# ~\anaconda3\envs\mask_rcnn\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    3955
#    3956     fetched = self._callable_fn(*array_vals,
# -> 3957                                 run_metadata=self.run_metadata)
#    3958     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3959     output_structure = nest.pack_sequence_as(
#
# ~\anaconda3\envs\mask_rcnn\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1480         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1481                                                self._handle, args,
# -> 1482                                                run_metadata_ptr)
#    1483         if run_metadata:
#    1484           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
